# %%
import findspark

findspark.init()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-d2b55f3d6626> in <module>
#       1 import findspark
#       2
# ----> 3 findspark.init()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     127
#     128     if not spark_home:
# --> 129         spark_home = find()
#     130
#     131     if not python_path:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\findspark.py in find()
#      34     if not spark_home:
#      35         raise ValueError(
# ---> 36             "Couldn't find Spark, make sure SPARK_HOME env is set"
#      37             " or Spark is in an expected location (e.g. from homebrew installation)."
#      38         )
#
# ValueError: Couldn't find Spark, make sure SPARK_HOME env is set or Spark is in an expected location (e.g. from homebrew installation).
